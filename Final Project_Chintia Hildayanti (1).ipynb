# %% [markdown]
# Final Project <br>
# Chintia Hildayanti<br>
# DS26

# %% [markdown]
# Dataset : Adult Census Income <br>
# sumber : https://archive.ics.uci.edu/dataset/2/adult <br>
# Objective : saya seorang pegawai pemerintah yang ingin melakukan analisis terhadap masyarakat Amerika Serikat yang memiliki penghasilan kurang dari 50.000 dollar per tahun, agar dapat diseleksi siapa saja yang dikecualikan dari pengenaan pajak penghasilan, mendapat bantuan sosial pemerintah, serta mendapat fasilitas pelatihan keterampilan.

# %% [markdown]
# ### Install & Import Package

# %%
# Install dalex
# !pip install dalex
#install scikit plot
# !pip install scikit-plot
# Out:
# Collecting dalex
#   Downloading dalex-1.7.1.tar.gz (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 19.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from dalex) (71.0.4)
# Requirement already satisfied: pandas>=1.5.3 in /usr/local/lib/python3.10/dist-packages (from dalex) (2.2.2)
# Requirement already satisfied: numpy>=1.23.3 in /usr/local/lib/python3.10/dist-packages (from dalex) (1.26.4)
# Requirement already satisfied: scipy>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from dalex) (1.13.1)
# Requirement already satisfied: plotly>=5.1.0 in /usr/local/lib/python3.10/dist-packages (from dalex) (5.24.1)
# Requirement already satisfied: tqdm>=4.61.2 in /usr/local/lib/python3.10/dist-packages (from dalex) (4.66.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.5.3->dalex) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.5.3->dalex) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.5.3->dalex) (2024.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly>=5.1.0->dalex) (9.0.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from plotly>=5.1.0->dalex) (24.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=1.5.3->dalex) (1.16.0)
# Building wheels for collected packages: dalex
#   Building wheel for dalex (setup.py) ... done
#   Created wheel for dalex: filename=dalex-1.7.1-py3-none-any.whl size=1042797 sha256=507071cee7e078d645db584200a4af28547632614bbeff2b0285e9a6e73540c2
#   Stored in directory: /root/.cache/pip/wheels/fe/c2/41/63e006b3312a4e17299bed5f83d985dea872368f9ab16bb20f
# Successfully built dalex
# Installing collected packages: dalex
# Successfully installed dalex-1.7.1
# Collecting scikit-plot
#   Downloading scikit_plot-0.3.7-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: matplotlib>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from scikit-plot) (3.7.1)
# Requirement already satisfied: scikit-learn>=0.18 in /usr/local/lib/python3.10/dist-packages (from scikit-plot) (1.5.2)
# Requirement already satisfied: scipy>=0.9 in /usr/local/lib/python3.10/dist-packages (from scikit-plot) (1.13.1)
# Requirement already satisfied: joblib>=0.10 in /usr/local/lib/python3.10/dist-packages (from scikit-plot) (1.4.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (1.4.7)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (2.8.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.18->scikit-plot) (3.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=1.4.0->scikit-plot) (1.16.0)
# Downloading scikit_plot-0.3.7-py3-none-any.whl (33 kB)
# Installing collected packages: scikit-plot
# Successfully installed scikit-plot-0.3.7

# %%
# import library yang dibutuhkan
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import dalex as dx
from scipy import stats
import joblib
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# ### Load The Dataset

# %%
# load dataset
df = pd.read_csv('https://archive.ics.uci.edu/static/public/2/data.csv')

# %% [markdown]
# ###Listing of attributes:
#
# US Census Bureau 1996 <br>
#
# * age: usia. <br>
# * workclass: kelas pekerja (Private, Self-emp-not-inc, Self-emp-inc, Federal-gov, Local-gov, State-gov, Without-pay, Never-worked).<br>
# * fnlwgt: final weight (sebuah bobot yang diberikan kepada setiap baris atau individu dalam dataset untuk mewakili jumlah orang dalam populasi yang memiliki karakteristik serupa seperti yang diwakili oleh baris tersebut).<br>
# * education: level pendidikan / pendidikan terakhir (Bachelors, Some-college, 11th, HS-grad, Prof-school, Assoc-acdm, Assoc-voc, 9th, 7th-8th, 12th, Masters, 1st-4th, 10th, Doctorate, 5th-6th, Preschool.)<br>
# * education-num: level pendidikan (numerik).<br>
# * marital-status: status pernikahan (Married-civ-spouse, Divorced, Never-married, Separated, Widowed, Married-spouse-absent, Married-AF-spouse).<br>
# * occupation: pekerjaan (Tech-support, Craft-repair, Other-service, Sales, Exec-managerial, Prof-specialty, Handlers-cleaners, Machine-op-inspct, Adm-clerical, Farming-fishing, Transport-moving, Priv-house-serv, Protective-serv, Armed-Forces).<br>
# * relationship: hubungan keluarga (Wife, Own-child, Husband, Not-in-family, Other-relative, Unmarried).<br>
# * race: ras (White, Asian-Pac-Islander, Amer-Indian-Eskimo, Other, Black).<br>
# * sex: jenis kelamin (Female, Male).<br>
# * capital-gain: keuntungan modal. <br>
# * capital-loss: kerugian modal. <br>
# * hours-per-week: jam kerja dalam seminggu.<br>
# * native-country: negara asal (United-States, Cambodia, England, Puerto-Rico, Canada, Germany, Outlying-US(Guam-USVI-etc), India, Japan, Greece, South, China, Cuba, Iran, Honduras, Philippines, Italy, Poland, Jamaica, Vietnam, Mexico, Portugal, Ireland, France, Dominican-Republic, Laos, Ecuador, Taiwan, Haiti, Columbia, Hungary, Guatemala, Nicaragua, Scotland, Thailand, Yugoslavia, El-Salvador, Trinadad&Tobago, Peru, Hong, Holand-Netherlands).<br>
# * income : >50K, <=50K (binary).<br>

# %%
# tampilkan dataset
df.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country income
# 0          2174             0              40  United-States  <=50K
# 1             0             0              13  United-States  <=50K
# 2             0             0              40  United-States  <=50K
# 3             0             0              40  United-States  <=50K
# 4             0             0              40           Cuba  <=50K

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             48842 non-null  int64
#  1   workclass       47879 non-null  object
#  2   fnlwgt          48842 non-null  int64
#  3   education       48842 non-null  object
#  4   education-num   48842 non-null  int64
#  5   marital-status  48842 non-null  object
#  6   occupation      47876 non-null  object
#  7   relationship    48842 non-null  object
#  8   race            48842 non-null  object
#  9   sex             48842 non-null  object
#  10  capital-gain    48842 non-null  int64
#  11  capital-loss    48842 non-null  int64
#  12  hours-per-week  48842 non-null  int64
#  13  native-country  48568 non-null  object
#  14  income          48842 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 5.6+ MB

# %% [markdown]
# ### Data Cleaning

# %%
# mengecek jumlah baris, missing value, presentase missing value, nilai unik dan nilai duplikat
pd.DataFrame({'count': df.shape[0],
              'nulls': df.isnull().sum(),
              'nulls%': df.isnull().mean() * 100,
              'cardinality': df.nunique(),
              'duplicated' : df.duplicated().sum()
             })
# Out:
#                 count  nulls    nulls%  cardinality  duplicated
# age             48842      0  0.000000           74          29
# workclass       48842    963  1.971664            9          29
# fnlwgt          48842      0  0.000000        28523          29
# education       48842      0  0.000000           16          29
# education-num   48842      0  0.000000           16          29
# marital-status  48842      0  0.000000            7          29
# occupation      48842    966  1.977806           15          29
# relationship    48842      0  0.000000            6          29
# race            48842      0  0.000000            5          29
# sex             48842      0  0.000000            2          29
# capital-gain    48842      0  0.000000          123          29
# capital-loss    48842      0  0.000000           99          29
# hours-per-week  48842      0  0.000000           96          29
# native-country  48842    274  0.560993           42          29
# income          48842      0  0.000000            4          29

# %% [markdown]
# Hasil :<br>
# terdapat 3 kolom yang mengandung missing value < 5% yaitu, workclass, occupation dan native-country <br>
# karena kolom-kolom tersebut mengandung missing value < 5% dan jika dijumlahkan tetap < 5% dari jumlah seluruh data <br>
# maka dari itu saya memilih untuk menghapus baris yang mengandung missing value tersebut,<br>
# dan terdapat 29 data duplikat saya juga memilih untuk menghapusnya.

# %%
# drop missing values
df.dropna(subset=['workclass','occupation','native-country'], inplace=True)

# %%
# drop data duplikat
df = df.drop_duplicates()

# %%
# mengecek kembali jumlah baris, missing value, presentase missing value, nilai unik dan nilai duplikat
pd.DataFrame({'count': df.shape[0],
              'nulls': df.isnull().sum(),
              'nulls%': df.isnull().mean() * 100,
              'cardinality': df.nunique(),
              'duplicated' : df.duplicated().sum()
             })
# Out:
#                 count  nulls  nulls%  cardinality  duplicated
# age             47592      0     0.0           74           0
# workclass       47592      0     0.0            9           0
# fnlwgt          47592      0     0.0        27946           0
# education       47592      0     0.0           16           0
# education-num   47592      0     0.0           16           0
# marital-status  47592      0     0.0            7           0
# occupation      47592      0     0.0           15           0
# relationship    47592      0     0.0            6           0
# race            47592      0     0.0            5           0
# sex             47592      0     0.0            2           0
# capital-gain    47592      0     0.0          122           0
# capital-loss    47592      0     0.0           98           0
# hours-per-week  47592      0     0.0           96           0
# native-country  47592      0     0.0           42           0
# income          47592      0     0.0            4           0

# %% [markdown]
# ### Exploratory Data Analysis

# %% [markdown]
# ####Statistical Summary

# %%
# statistical summary for numericals data
numericals = df.select_dtypes(include=['int64', 'float64']).columns
df[numericals].describe()
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  47592.000000  4.759200e+04   47592.000000   47592.00000  47592.000000
# mean      38.644541  1.897310e+05      10.091444    1091.80253     87.907022
# std       13.557307  1.055717e+05       2.567580    7489.46073    404.127864
# min       17.000000  1.228500e+04       1.000000       0.00000      0.000000
# 25%       28.000000  1.175848e+05       9.000000       0.00000      0.000000
# 50%       37.000000  1.782820e+05      10.000000       0.00000      0.000000
# 75%       48.000000  2.377130e+05      12.000000       0.00000      0.000000
# max       90.000000  1.490400e+06      16.000000   99999.00000   4356.000000
#
#        hours-per-week
# count    47592.000000
# mean        40.602895
# std         12.259716
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
# statistical summary for categoricals data
categoricals = df.select_dtypes(include=['object']).columns
df[categoricals].describe()
# Out:
#        workclass education      marital-status      occupation relationship  \
# count      47592     47592               47592           47592        47592
# unique         9        16                   7              15            6
# top      Private   HS-grad  Married-civ-spouse  Prof-specialty      Husband
# freq       33690     15437               21959            6105        19389
#
#          race    sex native-country income
# count   47592  47592          47592  47592
# unique      5      2             42      4
# top     White   Male  United-States  <=50K
# freq    40760  31918          42936  24698

# %% [markdown]
# ####Deteksi Outlier

# %%
# check outliers
plt.figure(figsize=(6, 4))
sns.boxplot(data=df[['age','fnlwgt','education-num','capital-gain','capital-loss','hours-per-week']])

plt.xticks(rotation=90)
plt.title('Boxplot for Continuous Data', fontsize=14)
plt.ylabel('Values', fontsize=10)
# Out:
# Text(0, 0.5, 'Values')

# %%
# membuat fungsi untuk melihat jumlah dan presentase outlier
def detect_outliers(df, column_name):

    # Menghitung IQR
    Q1 = df[column_name].quantile(0.25)
    Q3 = df[column_name].quantile(0.75)
    IQR = Q3 - Q1

    # Batas untuk mendeteksi outlier
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Filter outlier
    outliers = df[(df[column_name] < lower_bound) | (df[column_name] > upper_bound)]

    # Jumlah outlier
    jumlah_outlier = outliers.shape[0]

    # Persentase outlier
    persentase_outlier = (jumlah_outlier / df.shape[0]) * 100

    return jumlah_outlier, persentase_outlier

# %%
# deteksi jumlah outlier pada kolom final weight
detect_outliers(df, 'fnlwgt')
# Out:
# (1413, 2.968986384266263)

# %%
# deteksi jumlah outlier pada kolom capital gain
detect_outliers(df, 'capital-gain')
# Out:
# (3964, 8.329130946377543)

# %%
# deteksi jumlah outlier pada kolom capital loss
detect_outliers(df, 'capital-loss')
# Out:
# (2232, 4.689863842662632)

# %%
# deteksi jumlah outlier pada kolom hours per week
detect_outliers(df, 'hours-per-week')
# Out:
# (12947, 27.204151958312323)

# %%
# melihat data outlier pada kolom final weight >1.200.000
df.loc[df['fnlwgt'] > 1200000]
# Out:
#        age workclass   fnlwgt     education  education-num  \
# 8258    35   Private  1226583     Bachelors             13
# 14449   25   Private  1484705  Some-college             10
# 15569   29   Private  1268339       HS-grad              9
# 16739   45   Private  1366120     Assoc-voc             11
# 18138   39   Private  1455435    Assoc-acdm             12
# 40535   27   Private  1490400  Some-college             10
# 47084   31   Private  1210504          10th              6
#
#               marital-status       occupation   relationship   race     sex  \
# 8258      Married-civ-spouse            Sales        Husband  White    Male
# 14449               Divorced  Exec-managerial      Unmarried  White  Female
# 15569  Married-spouse-absent     Tech-support      Own-child  Black    Male
# 16739               Divorced    Other-service  Not-in-family  White  Female
# 18138              Separated     Craft-repair  Not-in-family  White    Male
# 40535     Married-civ-spouse  Exec-managerial        Husband  White    Male
# 47084     Married-civ-spouse     Adm-clerical           Wife  White  Female
#
#        capital-gain  capital-loss  hours-per-week native-country  income
# 8258              0             0              52  United-States    >50K
# 14449             0             0              25  United-States   <=50K
# 15569             0             0              40  United-States   <=50K
# 16739             0             0               8  United-States   <=50K
# 18138             0             0              40  United-States   <=50K
# 40535             0             0              40  United-States  <=50K.
# 47084             0             0              40  United-States  <=50K.

# %%
# melihat data outlier pada kolom capital gain >50.000 dollar
df.loc[df['capital-gain'] > 50000]
# Out:
#        age         workclass  fnlwgt    education  education-num  \
# 1246    54      Self-emp-inc  166459  Prof-school             15
# 1368    52           Private  152234      HS-grad              9
# 1482    53      Self-emp-inc  263925      HS-grad              9
# 1528    52           Private  118025    Bachelors             13
# 1616    46           Private  370119  Prof-school             15
# ...    ...               ...     ...          ...            ...
# 47739   32      Self-emp-inc  225053    Bachelors             13
# 48582   61  Self-emp-not-inc  151369      Masters             14
# 48591   36           Private  224566    Bachelors             13
# 48598   42           Private   32878    Bachelors             13
# 48629   59      Self-emp-inc  177271  Prof-school             15
#
#            marital-status       occupation   relationship                race  \
# 1246   Married-civ-spouse   Prof-specialty        Husband               White
# 1368   Married-civ-spouse  Exec-managerial        Husband  Asian-Pac-Islander
# 1482   Married-civ-spouse            Sales        Husband               White
# 1528   Married-civ-spouse  Exec-managerial        Husband               White
# 1616   Married-civ-spouse   Prof-specialty        Husband               White
# ...                   ...              ...            ...                 ...
# 47739  Married-civ-spouse  Exec-managerial        Husband               White
# 48582  Married-civ-spouse   Prof-specialty        Husband               White
# 48591       Never-married   Prof-specialty  Not-in-family               White
# 48598  Married-civ-spouse   Prof-specialty        Husband               White
# 48629  Married-civ-spouse  Exec-managerial        Husband               White
#
#         sex  capital-gain  capital-loss  hours-per-week native-country income
# 1246   Male         99999             0              60  United-States   >50K
# 1368   Male         99999             0              40          Japan   >50K
# 1482   Male         99999             0              40  United-States   >50K
# 1528   Male         99999             0              50  United-States   >50K
# 1616   Male         99999             0              60  United-States   >50K
# ...     ...           ...           ...             ...            ...    ...
# 47739  Male         99999             0              60  United-States  >50K.
# 48582  Male         99999             0              30  United-States  >50K.
# 48591  Male         99999             0              45  United-States  >50K.
# 48598  Male         99999             0              42  United-States  >50K.
# 48629  Male         99999             0              84  United-States  >50K.
#
# [240 rows x 15 columns]

# %%
# melihat data outlier pada kolom hours per week > 90 jam
df.loc[df['hours-per-week'] > 90]
# Out:
#        age         workclass  fnlwgt     education  education-num  \
# 272     50  Self-emp-not-inc   30653       Masters             14
# 935     37           Private  176900       HS-grad              9
# 1172    25           Private  404616       Masters             14
# 1887    55  Self-emp-not-inc  184425  Some-college             10
# 2920    63  Self-emp-not-inc   26904       HS-grad              9
# ...    ...               ...     ...           ...            ...
# 45475   60           Private  197311       HS-grad              9
# 45888   52  Self-emp-not-inc  284648       HS-grad              9
# 45929   42      Self-emp-inc  203233   Prof-school             15
# 47760   48           Private  250736       HS-grad              9
# 48130   43      Self-emp-inc  314739  Some-college             10
#
#            marital-status        occupation   relationship   race     sex  \
# 272    Married-civ-spouse   Farming-fishing        Husband  White    Male
# 935    Married-civ-spouse      Craft-repair        Husband  White    Male
# 1172   Married-civ-spouse   Farming-fishing  Not-in-family  White    Male
# 1887   Married-civ-spouse   Farming-fishing        Husband  White    Male
# 2920   Married-civ-spouse   Farming-fishing        Husband  White    Male
# ...                   ...               ...            ...    ...     ...
# 45475            Divorced   Priv-house-serv      Unmarried  White  Female
# 45888            Divorced   Exec-managerial      Unmarried  White  Female
# 45929  Married-civ-spouse    Prof-specialty        Husband  White    Male
# 47760  Married-civ-spouse  Transport-moving        Husband  Black    Male
# 48130  Married-civ-spouse   Exec-managerial        Husband  White    Male
#
#        capital-gain  capital-loss  hours-per-week native-country  income
# 272            2407             0              98  United-States   <=50K
# 935               0             0              99  United-States    >50K
# 1172              0             0              99  United-States    >50K
# 1887              0             0              99  United-States    >50K
# 2920              0             0              98  United-States   <=50K
# ...             ...           ...             ...            ...     ...
# 45475             0             0              99  United-States  <=50K.
# 45888             0             0              99  United-States   >50K.
# 45929         99999             0              99  United-States   >50K.
# 47760             0             0              99  United-States  <=50K.
# 48130             0             0              92  United-States   >50K.
#
# [164 rows x 15 columns]

# %% [markdown]
# Kesimpulan :<br>
# * outlier kolom age dianggap masih wajar karena ada manusia yang hidup sampai 90 tahun, dan masih bekerja (asumsi saya data tersebut benar), saya memilih membiarkan saja dari pada menghapusnya yang beresiko kehilangan insight dari data tersebut.
# * outlier kolom final weight juga dianggap masih wajar karena ini angka dari datanya, jadi saya memilih membiarkan saja
# * outlier kolom education num, dibiarkan saja karena itu nomor jenjang pendidikan
# * outlier kolom capital gain dan capital loss dianggap masih wajar jadi di biarkan saja, karena bisnis sangat fleksibel (bisa sangat untung, bisa juga sangat merugi)
# * outlier kolom hours per week dianggap masih wajar, asumsi saya bahwa benar ada orang yang jam kerjanya selama seminggu mencapai 99 jam, jadi dibiarkan saja.
# * saya akan mengatasi outlier ini dengan standarisasi (robust scaler)

# %% [markdown]
# #### Visualisasi

# %%
# menghapus titik yang tidak perlu pada data, agar hanya ada 2 unik value
df['income'] = df['income'].replace({'>50K.' :'>50K', '<=50K.':'<=50K'})

# %%
# menghitung jumlah income
income_counts = df['income'].value_counts()

# membuat pie plot income
plt.figure(figsize=(5, 5))
plt.pie(income_counts, labels=income_counts.index, autopct='%1.1f%%', startangle=90, colors=['blue','lightblue'])
plt.title('Percentage of Income')
plt.axis('equal')
plt.show()

# %% [markdown]
# Hasil : Imbalance data target, sehingga hasil evaluasi nanti tidak bisa pakai akurasi

# %%
# membuat grafik distribusi usia
df['age'].plot(kind='hist', bins=30, title='Age Distribution', color='lightblue')
plt.xlabel('Age')
plt.show()

# %% [markdown]
# Hasil :<br>
# * Usia 20 hingga sekitar 40 tahun adalah kelompok usia dengan jumlah individu tertinggi, dengan frekuensi mencapai puncak sekitar 3.500-4.000 individu di beberapa interval usia.<br>
# * Usia 30-an tampak menjadi kelompok paling dominan.<br>
# *Jumlah individu menurun secara signifikan setelah usia 50 tahun, dan sangat sedikit orang yang berusia di atas 70 tahun, ini masuk akal.<br>

# %%
# membuat correlation heatmap
corr_matrix = df[['age', 'fnlwgt', 'education-num', 'capital-gain', 'capital-loss', 'hours-per-week']].corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Heatmap Korelasi Variabel Numerik')
plt.show()

# %% [markdown]
# Hasil : tidak ada kolom yang saling berkorelasi tinggi.

# %% [markdown]
# ### Deep Dive Analysis

# %%
# merubah value ? menjadi Others agar lebih mudah dibaca
df['workclass'] = df['workclass'].replace({'?' :'Others'})

# %%
# membuat barplot pengaruh kelas pekerja terhadap income
plt.figure(figsize=(5, 4))
sns.countplot(x='workclass', hue='income', data=df,  palette=['lightblue', 'blue'])
plt.title('The Impact Of The Workclass On Income')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Hasil :<br>
# * kelas pekerja private yang paling banyak jumlahnya baik yang berpenghasilan <=50.000 dollar maupun >50.000 dollar. <br>
# * diseluruh kelas, jumlah orang yang memiliki penghasilan >50.000 dollar jauh lebih sedikit tetapi pada kelas self employment income (pengusaha swasta) jauh lebih banyak, ini masuk akal
# * jadi kelas pekerja berpengaruh terhadap income.

# %%
# membuat plot distribusi income terhadap tingkat pendidikan
plt.figure(figsize=(5, 4))
sns.countplot(x='education', hue='income', data=df, palette=['lightblue', 'blue'])
plt.xticks(rotation=90)
plt.title('Income Distribution by Education Level')
plt.show()

# %% [markdown]
# Hasil: <br>
# * jumlah orang dengan jenjang pendidikan SMA paling mendominasi, tetapi yang memiliki penghasilan >50.000 dollar sangat sedikit
# * jenjang pendidikan master, doctorate dan prof-school memiliki jumlah orang yang berpenghasilan >50.000 jauh lebih banyak
# * artinya jenjang pendidikan berpengaruh terhadap income.

# %%
# membuat plot distribusi income terhadap tingkat pendidikan
plt.figure(figsize=(5, 4))
sns.countplot(x='occupation', hue='income', data=df, palette=['lightblue', 'blue'])
plt.xticks(rotation=90)
plt.title('The Effect of Occupation on Income')
plt.show()

# %% [markdown]
# Hasil :
# * orang yang memiliki penghasilan diatas $50.000 paling banyak pada exec-managerial and prof-specialty
# * pekerjaan mempengaruhi income

# %%
# membuat barplot pengaruh ras terhadap income
sns.countplot(x='race', hue='income', data=df, palette=['lightblue', 'blue'])
plt.title('The Impact of the Race on Income ')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Hasil :<br>
# * mayoritas masyarakat dari ras kulit putih
# * ras tidak mempengaruhi penghasilan

# %%
# membuat barplot hubungan keluarga terhadap income
sns.countplot(x='relationship', hue='income', data=df, palette=['lightblue', 'blue'])
plt.title('The Impact of Relationship on Income')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Hasil :
# * Not in family dan husband mendominasi
# * husband dan wife paling banyak yang memiliki penghasilan >$ 50.000
# * relationship mempengaruhi income

# %%
# membuat bar chart pengaruh status pernikahan terhadap income
plt.figure(figsize=(5, 3))
sns.countplot(x='marital-status', hue='income', data=df, palette=['lightblue', 'blue'])
plt.title('The Impact of Marital Status on Income')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Hasil :
# * never married dan married civil spouse mendominasi data
# * orang yang memiliki penghasilan >$50.000 paling banyak pada married civil spouse
# * status pernikahan mempengaruhi income

# %%
# membuat barplot jenis kelamin
sns.countplot(x='sex', hue='income', data=df, palette=['lightblue', 'blue'])
plt.title('The Impact of Sex on Income')
plt.show()

# %% [markdown]
# Hasil :<br>
# * jumlah laki-laki lebih banyak dari perempuan
# * pada keduanya, orang yang memiliki penghasilan >50.000 dollar jauh lebih sedikit
# * jenis kelamin mempengaruhi income.

# %%
# membuat boxplot capital gain
sns.boxplot(x='income', y='capital-gain', data=df)
plt.title('The Impact of Capital-Gain on Income')
plt.show()

# %% [markdown]
# Hasil :<br>
# Hubungan antara capital-gain dan pendapatan tampak tidak terlalu kuat di mayoritas populasi, tetapi outlier menunjukkan bahwa orang dengan capital-gain tinggi cenderung lebih mungkin memiliki pendapatan >50.000 dollar

# %%
# membuat boxplot capital gain
sns.boxplot(x='income', y='capital-loss', data=df)
plt.title('The Impact of Capital-Loss on Income')
plt.show()

# %% [markdown]
# Hasil :
# Hubungan antara capital-loss dan pendapatan tampak tidak terlalu kuat di mayoritas populasi, tetapi outlier menunjukkan bahwa orang dengan capital-loss tinggi cenderung lebih mungkin memiliki pendapatan <50.000 dollar

# %%
# membuat boxplot distribusi usia terhadap income
sns.boxplot(x='income', y='age', data=df, color='lightblue')
plt.title('The Impact of Age Distribution on Income')
plt.show()

# %% [markdown]
# Hasil: terlihat dari nilai median yang cukup berbeda, artinya umur mempengaruhi penghasilan

# %%
# membuat boxplot pengaruh jam kerja perminggu terhadap income
sns.boxplot(x='income', y='hours-per-week', data=df, color='lightblue')
plt.title('The Impact Of Working Hours In A Week On Income')
plt.show()

# %% [markdown]
# Hasil: terlihat dari nilai median yang cukup berbeda, artinya jam kerja mempengaruhi penghasilan

# %%
# membuat pair plot numerikal kolom terhadap taget
sns.pairplot(df, hue='income', vars=['age', 'education-num', 'hours-per-week', 'capital-gain', 'capital-loss'])
plt.show()

# %% [markdown]
# ###Feature Engineering

# %%
# melakukan label encoding pada kolom sex
label_encoder = LabelEncoder()

df['sex_encoded'] = label_encoder.fit_transform(df['sex'])

# %%
# Membuat kolom baru income_encoded berdasarkan kolom income
df['income_encoded'] = df['income'].apply(lambda x: 1 if x == '<=50K' else 0)

# %%
# Ganti 'United-States' menjadi 1, dan negara lainnya menjadi 0

df['native-country'] = df['native-country'].apply(lambda x: 1 if x == 'United-States' else 0).astype(int)

# %%
freq_encoding_marital_status = df['marital-status'].value_counts()
freq_encoding_marital_status
# Out:
# marital-status
# Married-civ-spouse       21959
# Never-married            15536
# Divorced                  6523
# Separated                 1497
# Widowed                   1443
# Married-spouse-absent      600
# Married-AF-spouse           34
# Name: count, dtype: int64

# %%
df['occupation'] = df['occupation'].replace({'?' :'Other'})
freq_encoding_occupation = df['occupation'].value_counts()
freq_encoding_occupation
# Out:
# occupation
# Prof-specialty       6105
# Craft-repair         6084
# Exec-managerial      6056
# Adm-clerical         5586
# Sales                5474
# Other-service        4887
# Machine-op-inspct    3003
# Transport-moving     2341
# Handlers-cleaners    2065
# Other                1843
# Farming-fishing      1482
# Tech-support         1435
# Protective-serv       981
# Priv-house-serv       236
# Armed-Forces           14
# Name: count, dtype: int64

# %%
freq_encoding_relationship = df['relationship'].value_counts()
freq_encoding_relationship
# Out:
# relationship
# Husband           19389
# Not-in-family     12265
# Own-child          7223
# Unmarried          5021
# Wife               2253
# Other-relative     1441
# Name: count, dtype: int64

# %%
freq_encoding_workclass = df['race'].value_counts()
freq_encoding_workclass
# Out:
# race
# White                 40760
# Black                  4533
# Asian-Pac-Islander     1446
# Amer-Indian-Eskimo      460
# Other                   393
# Name: count, dtype: int64

# %%
# melakukan frequency encoding pada kategorikal kolom
cats = ['workclass', 'marital-status', 'occupation', 'relationship', 'race']

for column in df[cats]:
    frequency_encoding = df[column].value_counts()
    df[column + '_encoded'] = df[column].map(frequency_encoding)

df.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  ...  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male  ...
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male  ...
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male  ...
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male  ...
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female  ...
#
#    hours-per-week  native-country  income  sex_encoded income_encoded  \
# 0              40               1   <=50K            1              1
# 1              13               1   <=50K            1              1
# 2              40               1   <=50K            1              1
# 3              40               1   <=50K            1              1
# 4              40               0   <=50K            0              1
#
#    workclass_encoded  marital-status_encoded  occupation_encoded  \
# 0               1965                   15536                5586
# 1               3837                   21959                6056
# 2              33690                    6523                2065
# 3              33690                   21959                2065
# 4              33690                   21959                6105
#
#    relationship_encoded  race_encoded
# 0                 12265         40760
# 1                 19389         40760
# 2                 12265         40760
# 3                 19389          4533
# 4                  2253          4533
#
# [5 rows x 22 columns]

# %% [markdown]
# * melakukan label encoding pada kolom sex
# * melakukan label encoding pada kolom native country dengan hanya menjadikan 2 unik value masyarakat asli Amerika Serikan dan bukan masyarakat asli (dengan asumsi asal negara mempengaruhi target).
# * membuat kolom baru yang berisi nilai binary dari kolom income dan dijadikan target
# * melakukan frequency encoding pada kolom-kolom kategorikal lainnya yang mengandung nilai unik >2

# %% [markdown]
# ### Feature Selection

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 47592 entries, 0 to 48841
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   age                     47592 non-null  int64
#  1   workclass               47592 non-null  object
#  2   fnlwgt                  47592 non-null  int64
#  3   education               47592 non-null  object
#  4   education-num           47592 non-null  int64
#  5   marital-status          47592 non-null  object
#  6   occupation              47592 non-null  object
#  7   relationship            47592 non-null  object
#  8   race                    47592 non-null  object
#  9   sex                     47592 non-null  object
#  10  capital-gain            47592 non-null  int64
#  11  capital-loss            47592 non-null  int64
#  12  hours-per-week          47592 non-null  int64
#  13  native-country          47592 non-null  int64
#  14  income                  47592 non-null  object
#  15  sex_encoded             47592 non-null  int64
#  16  income_encoded          47592 non-null  int64
#  17  workclass_encoded       47592 non-null  int64
#  18  marital-status_encoded  47592 non-null  int64
#  19  occupation_encoded      47592 non-null  int64
#  20  relationship_encoded    47592 non-null  int64
#  21  race_encoded            47592 non-null  int64
# dtypes: int64(14), object(8)
# memory usage: 8.4+ MB

# %% [markdown]
# * menghapus kolom education karena sudah diwakili oleh kolom education-num
# * menghapus kolom income karena sudah diwakili oleh kolom income_encoded yang berisi nilai numerik binary
# * menghapus kolom kategorik yang sudah dilakukan frequency encoding sebelumnya

# %%
# drop kolom yang tidak dibutuhkan
df_new = df.select_dtypes(exclude=['object'])
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 47592 entries, 0 to 48841
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   age                     47592 non-null  int64
#  1   fnlwgt                  47592 non-null  int64
#  2   education-num           47592 non-null  int64
#  3   capital-gain            47592 non-null  int64
#  4   capital-loss            47592 non-null  int64
#  5   hours-per-week          47592 non-null  int64
#  6   native-country          47592 non-null  int64
#  7   sex_encoded             47592 non-null  int64
#  8   income_encoded          47592 non-null  int64
#  9   workclass_encoded       47592 non-null  int64
#  10  marital-status_encoded  47592 non-null  int64
#  11  occupation_encoded      47592 non-null  int64
#  12  relationship_encoded    47592 non-null  int64
#  13  race_encoded            47592 non-null  int64
# dtypes: int64(14)
# memory usage: 5.4 MB

# %% [markdown]
# ### Multicollinearity Handling

# %%
# create correlation heatmap of numericals data

plt.figure(figsize=(12, 4))
corr_matrix = df_new.corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap Numerical Variables')
plt.show()

# %% [markdown]
# Interpretasi : tidak ada kolom yang saling berkorelasi tinggi (>0.80)

# %% [markdown]
# ### Train Test Split

# %%
# Train test split sebelum standarisasi

feature = df_new.drop('income_encoded', axis=1)
target = df_new['income_encoded']

ftr_train, ftr_test, tg_train,tg_test = train_test_split(feature,target,
                                                test_size = 0.20,
                                                random_state = 42)

# %% [markdown]
# ### Standarization (Feature Scalling)

# %%
# robust scalling

scaler = RobustScaler()
scaler.fit(ftr_train)
X_std = scaler.transform(feature)
df_std = pd.DataFrame(data = X_std, columns = feature.columns)
df_std.head()
# Out:
#     age    fnlwgt  education-num  capital-gain  capital-loss  hours-per-week  \
# 0  0.10 -0.838353       1.000000        2174.0           0.0             0.0
# 1  0.65 -0.790204       1.000000           0.0           0.0            -5.4
# 2  0.05  0.309335      -0.333333           0.0           0.0             0.0
# 3  0.80  0.467824      -1.000000           0.0           0.0             0.0
# 4 -0.45  1.329342       1.000000           0.0           0.0             0.0
#
#    native-country  sex_encoded  workclass_encoded  marital-status_encoded  \
# 0             0.0          0.0          -1.062707                0.000000
# 1             0.0          0.0          -1.000000                1.000000
# 2             0.0          0.0           0.000000               -1.403238
# 3             0.0          0.0           0.000000                1.000000
# 4            -1.0         -1.0           0.000000                1.000000
#
#    occupation_encoded  relationship_encoded  race_encoded
# 0            0.036352              0.000000           0.0
# 1            0.188900              0.585566           0.0
# 2           -1.106459              0.000000           0.0
# 3           -1.106459              0.585566      -36227.0
# 4            0.204804             -0.822949      -36227.0

# %%
# Train test split setelah standarisasi

feature2 = df_std
target2 = df_new['income_encoded']

ftr2_train, ftr2_test, tg2_train,tg2_test = train_test_split(feature2,target2,
                                                test_size = 0.20,
                                                random_state = 42)

# %% [markdown]
# ### Model Training

# %%
# define & training logistic regression model
logreg = LogisticRegression(random_state=42)
logreg.fit(ftr2_train, tg2_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(random_state=42)

# %%
# define & training decision tree classifier model
decision_tree_clf = DecisionTreeClassifier(random_state=42)
decision_tree_clf.fit(ftr2_train, tg2_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
# define & training random forest model
random_forest_clf = RandomForestClassifier(random_state=42)
random_forest_clf.fit(ftr2_train, tg2_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
# define & XGBoost classifier model
xgb_clf = XGBClassifier(random_state=42)
xgb_clf.fit(ftr2_train, tg2_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=42, ...)

# %% [markdown]
# ### Model Evaluation

# %% [markdown]
# saya menggunakan metrik evaluasi f1 score karena saya berasumsi baik false positif maupun false negatif sama-sama penting.<br>
# agar tidak salah sasaran, jadi perlu diperlu diperhatikan keduanya

# %% [markdown]
# Logistik Regression

# %%
# evaluasi model logistic regression pada data train
logreg_pred_train = logreg.predict(ftr2_train)
print(classification_report(tg2_train, logreg_pred_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      0.56      0.62      9194
#            1       0.87      0.93      0.90     28879
#
#     accuracy                           0.84     38073
#    macro avg       0.79      0.74      0.76     38073
# weighted avg       0.83      0.84      0.83     38073

# %%
# evaluasi model logistic regression pada data test
logreg_pred_test = logreg.predict(ftr2_test)
print(classification_report(tg2_test, logreg_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.72      0.55      0.63      2345
#            1       0.86      0.93      0.90      7174
#
#     accuracy                           0.84      9519
#    macro avg       0.79      0.74      0.76      9519
# weighted avg       0.83      0.84      0.83      9519

# %% [markdown]
# Interpretasi : model logistic regression fit untuk dataset ini, karena nilai f1 score dari data train dan data test sama hasilnya yaitu 90%

# %% [markdown]
# Decision Tree

# %%
# evaluasi model decision tree pada data train
dt_pred_train = decision_tree_clf.predict(ftr2_train)
print(classification_report(tg2_train, dt_pred_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      9194
#            1       1.00      1.00      1.00     28879
#
#     accuracy                           1.00     38073
#    macro avg       1.00      1.00      1.00     38073
# weighted avg       1.00      1.00      1.00     38073

# %%
# evaluasi model decision tree pada data test
dt_pred_test = decision_tree_clf.predict(ftr2_test)
print(classification_report(tg2_test, dt_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.62      0.63      0.63      2345
#            1       0.88      0.87      0.88      7174
#
#     accuracy                           0.81      9519
#    macro avg       0.75      0.75      0.75      9519
# weighted avg       0.82      0.81      0.81      9519

# %% [markdown]
# Interpretasi : model decision tree overfit pada dataset ini, karena nilai f1 score dari data train dan data test jauh berbeda hasilnya yaitu 100% dan 88%

# %% [markdown]
# Random Forest

# %%
# evaluasi model random forest pada data train
rf_pred_train = random_forest_clf.predict(ftr2_train)
print(classification_report(tg2_train, rf_pred_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      9194
#            1       1.00      1.00      1.00     28879
#
#     accuracy                           1.00     38073
#    macro avg       1.00      1.00      1.00     38073
# weighted avg       1.00      1.00      1.00     38073

# %%
# evaluasi model random forest pada data test
rf_pred_test = random_forest_clf.predict(ftr2_test)
print(classification_report(tg2_test, rf_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.63      0.68      2345
#            1       0.88      0.92      0.90      7174
#
#     accuracy                           0.85      9519
#    macro avg       0.81      0.78      0.79      9519
# weighted avg       0.85      0.85      0.85      9519

# %% [markdown]
# Interpretasi : model random forest overfit pada dataset ini, karena nilai f1 score dari data train dan data test jauh berbeda hasilnya yaitu 100% dan 90%

# %% [markdown]
# XGBoost

# %%
# evaluasi model XGBoost Classifier pada data train
xgb_pred_train = xgb_clf.predict(ftr2_train)
print(classification_report(tg2_train, xgb_pred_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.72      0.78      9194
#            1       0.92      0.96      0.94     28879
#
#     accuracy                           0.90     38073
#    macro avg       0.88      0.84      0.86     38073
# weighted avg       0.90      0.90      0.90     38073

# %%
# evaluasi model XGBoost Classifier pada data test
xgb_pred_test = xgb_clf.predict(ftr2_test)
print(classification_report(tg2_test, xgb_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.67      0.72      2345
#            1       0.90      0.94      0.92      7174
#
#     accuracy                           0.87      9519
#    macro avg       0.84      0.80      0.82      9519
# weighted avg       0.87      0.87      0.87      9519

# %% [markdown]
# Interpretasi : model xgboost fit untuk dataset ini, karena nilai f1 score dari data train dan data test hampir sama hasilnya yaitu 94% dan 92%

# %% [markdown]
# sejauh ini saya memilih model xgboost sebagai model terbaik karena modelnya fit dan memiliki nilai f1 score paling tinggi dari model-model lainnya, lalu saya coba lakukan hyperparameter tunning pada model terpilih yaitu xgboost.

# %% [markdown]
# Hyperparameter tunning

# %%
# hyperparameter tuning menggunakan model terbaik yaitu XGBoost Classifier

parameters = {
    'n_estimators': [10, 20, 30, 40, 50],
    'max_depth': [1, 2, 3, 4, 5]
}

# using GridSearchCV with f1 as scoring metric
xgb_clf_gridcv = GridSearchCV(xgb_clf, parameters, cv=5, scoring='f1')

# fitting the model
xgb_clf_gridcv.fit(ftr2_train, tg2_train)

# print best parameters
print("Best parameters found: ", xgb_clf_gridcv.best_params_)
# Out:
# Best parameters found:  {'max_depth': 5, 'n_estimators': 40}

# %% [markdown]
# best parameter:<br>
# max_depth: 5<br>
# n_estimator: 50<br>
# f1: 92% (pembulatan keatas)

# %%
# menampilkan result best parameter berdasarkan rank
cv_result = pd.DataFrame(xgb_clf_gridcv.cv_results_)
retain_cols = ['params','mean_test_score','rank_test_score']
cv_result[retain_cols].sort_values('rank_test_score')
# Out:
#                                   params  mean_test_score  rank_test_score
# 23  {'max_depth': 5, 'n_estimators': 40}         0.918262                1
# 22  {'max_depth': 5, 'n_estimators': 30}         0.918004                2
# 24  {'max_depth': 5, 'n_estimators': 50}         0.917984                3
# 18  {'max_depth': 4, 'n_estimators': 40}         0.917681                4
# 19  {'max_depth': 4, 'n_estimators': 50}         0.917604                5
# 17  {'max_depth': 4, 'n_estimators': 30}         0.916824                6
# 14  {'max_depth': 3, 'n_estimators': 50}         0.916422                7
# 21  {'max_depth': 5, 'n_estimators': 20}         0.916377                8
# 13  {'max_depth': 3, 'n_estimators': 40}         0.915365                9
# 16  {'max_depth': 4, 'n_estimators': 20}         0.914874               10
# 12  {'max_depth': 3, 'n_estimators': 30}         0.914414               11
# 20  {'max_depth': 5, 'n_estimators': 10}         0.912946               12
# 9   {'max_depth': 2, 'n_estimators': 50}         0.912760               13
# 8   {'max_depth': 2, 'n_estimators': 40}         0.911495               14
# 11  {'max_depth': 3, 'n_estimators': 20}         0.911374               15
# 15  {'max_depth': 4, 'n_estimators': 10}         0.910538               16
# 7   {'max_depth': 2, 'n_estimators': 30}         0.910388               17
# 10  {'max_depth': 3, 'n_estimators': 10}         0.909304               18
# 6   {'max_depth': 2, 'n_estimators': 20}         0.908496               19
# 4   {'max_depth': 1, 'n_estimators': 50}         0.908014               20
# 3   {'max_depth': 1, 'n_estimators': 40}         0.907227               21
# 2   {'max_depth': 1, 'n_estimators': 30}         0.906799               22
# 5   {'max_depth': 2, 'n_estimators': 10}         0.906368               23
# 1   {'max_depth': 1, 'n_estimators': 20}         0.905181               24
# 0   {'max_depth': 1, 'n_estimators': 10}         0.900131               25

# %%
# menampilkan confusion matrix
fig, ax = plt.subplots(figsize=(8,5))
xgb_pred = xgb_clf_gridcv.best_estimator_.predict(ftr2_test)

cm = confusion_matrix(tg2_test, xgb_pred, labels=xgb_clf_gridcv.best_estimator_.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                             display_labels=xgb_clf_gridcv.best_estimator_.classes_)
disp.plot(ax=ax, cmap='Blues')
plt.show()

# %% [markdown]
# Interpretasi :
# * model memprediksi 411 orang berpenghasilan >50K dollar padahal sebenarnya berpenghasilan <=50K dollar (false negatif)
# * model memprediksi 828 orang berpenghasilan <=50K dollar padahal sebenarnya berpenghasilan >50K dollar (false positif)

# %% [markdown]
# ### Model Agnostik

# %%
# inisiasi explainer untuk logistic regression model
logreg_exp = dx.Explainer(logreg, ftr2_train, tg2_train, label = "Logistic Regression Interpretation")
# Out:
# Preparation of a new explainer is initiated
#
#   -> data              : 38073 rows 13 cols
#   -> target variable   : Parameter 'y' was a pandas.Series. Converted to a numpy.ndarray.
#   -> target variable   : 38073 values
#   -> model_class       : sklearn.linear_model._logistic.LogisticRegression (default)
#   -> label             : Logistic Regression Interpretation
#   -> predict function  : <function yhat_proba_default at 0x7cb383eb2050> will be used (default)
#   -> predict function  : Accepts pandas.DataFrame and numpy.ndarray.
#   -> predicted values  : min = 9.38e-16, mean = 0.745, max = 1.0
#   -> model type        : classification will be used (default)
#   -> residual function : difference between y and yhat (default)
#   -> residuals         : min = -0.996, mean = 0.0137, max = 1.0
#   -> model_info        : package sklearn
#
# A new explainer has been created!

# %%
# inisiasi explainer untuk XGBoost model
xgb_exp = dx.Explainer(xgb_clf, ftr2_train, tg2_train, label = "XGBoost Interpretation")
# Out:
# Preparation of a new explainer is initiated
#
#   -> data              : 38073 rows 13 cols
#   -> target variable   : Parameter 'y' was a pandas.Series. Converted to a numpy.ndarray.
#   -> target variable   : 38073 values
#   -> model_class       : xgboost.sklearn.XGBClassifier (default)
#   -> label             : XGBoost Interpretation
#   -> predict function  : <function yhat_proba_default at 0x7cb383eb2050> will be used (default)
#   -> predict function  : Accepts pandas.DataFrame and numpy.ndarray.
#   -> predicted values  : min = 1.99e-05, mean = 0.758, max = 1.0
#   -> model type        : classification will be used (default)
#   -> residual function : difference between y and yhat (default)
#   -> residuals         : min = -0.997, mean = 2.14e-05, max = 0.968
#   -> model_info        : package xgboost
#
# A new explainer has been created!

# %% [markdown]
# ###Permutation Feature Importance

# %%
# visualisasi permutation feature importance untuk logistic regression Model
plt.figure(figsize=(8, 10))
logreg_exp.model_parts().plot()
ax.set_xlim(left=0)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="a9a1ebd9-a964-4ab1-b5bb-ebb6c0aa5da2" class="plotly-graph-div" style="height:383.0px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a9a1ebd9-a964-4ab1-b5bb-ebb6c0aa5da2")) {                    Plotly.newPlot(                        "a9a1ebd9-a964-4ab1-b5bb-ebb6c0aa5da2",                        [{"base":0.11643359275183589,"hoverinfo":"text","hoverlabel":{"bgcolor":"rgba(0,0,0,0.8)"},"hovertext":["Model: Logistic Regression Interpretation loss after\u003cbr\u003evariable: marital-status_encoded is permuted: 0.198\u003cbr\u003eDrop-out loss change: +0.081","Model: Logistic Regression Interpretation loss after\u003cbr\u003evariable: education-num is permuted: 0.169\u003cbr\u003eDrop-out loss change: +0.052","Model: Logistic Regression Interpretation loss after\u003cbr\u003evariable: capital-gain is permuted: 0.167\u003cbr\u003eDrop-out loss change: +0.05","Model: Logistic Regression Interpretation loss after\u003cbr\u003evariable: age is permuted: 0.131\u003cbr\u003eDrop-out loss change: +0.014","Model: Logistic Regression Interpretation loss after\u003cbr\u003evariable: hours-per-week is permuted: 0.129\u003cbr\u003eDrop-out loss change: +0.013","Model: Logistic Regression Interpretation loss after\u003cbr\u003evariable: capital-loss is permuted: 0.126\u003cbr\u003eDrop-out loss change: +0.01","Model: Logistic Regression Interpretation loss after\u003cbr\u003evariable: occupation_encoded is permuted: 0.124\u003cbr\u003eDrop-out loss change: +0.008","Model: Logistic Regression Interpretation loss after\u003cbr\u003evariable: sex_encoded is permuted: 0.119\u003cbr\u003eDrop-out loss change: +0.002","Model: Logistic Regression Interpretation loss after\u003cbr\u003evariable: relationship_encoded is permuted: 0.117\u003cbr\u003eDrop-out loss change: +0.001","Model: Logistic Regression Interpretation loss after\u003cbr\u003evariable: race_encoded is permuted: 0.117\u003cbr\u003eDrop-out loss change: +0.0"],"marker":{"color":"#46bac2"},"orientation":"h","showlegend":false,"text":["+0.081","+0.052","+0.05","+0.014","+0.013","+0.01","+0.008","+0.002","+0.001","+0.0"],"textposition":"outside","x":[0.08114946920332354,0.05208734448153936,0.050258120891419275,0.01424119613635623,0.012708860150389176,0.009654837512301354,0.007772922848971839,0.0024737494664024,0.0008492739254658821,0.00040512818516287574],"y":["marital-status_encoded","education-num","capital-gain","age","hours-per-week","capital-loss","occupation_encoded","sex_encoded","relationship_encoded","race_encoded"],"type":"bar","xaxis":"x","yaxis":"y"}],                        {"template":{"data":{"scatter":[{"type":"scatter"}]}},"xaxis":{"anchor":"y","domain":[0.0,1.0],"type":"linear","gridwidth":2,"zeroline":false,"automargin":true,"ticks":"outside","tickcolor":"white","ticklen":3,"fixedrange":true,"range":[0.10303106348490743,0.20991593132084446]},"yaxis":{"anchor":"x","domain":[0.0,1.0],"type":"category","autorange":"reversed","gridwidth":2,"automargin":true,"ticks":"outside","tickcolor":"white","ticklen":10,"fixedrange":true},"annotations":[{"font":{"size":16},"showarrow":false,"text":"Logistic Regression Interpretation","x":0.5,"xanchor":"center","xref":"paper","y":1.0,"yanchor":"bottom","yref":"paper"},{"font":{"size":16},"showarrow":false,"text":"drop-out loss","x":0.5,"xanchor":"center","xref":"paper","y":0,"yanchor":"top","yref":"paper","yshift":-30}],"shapes":[{"line":{"color":"#371ea3","dash":"dot","width":1.5},"type":"line","x0":0.11643359275183589,"x1":0.11643359275183589,"xref":"x","y0":-1,"y1":10,"yref":"y"}],"title":{"text":"Variable Importance","x":0.15},"font":{"color":"#371ea3"},"margin":{"t":78,"b":71,"r":30},"height":383.0},                        {"displaylogo": false, "staticPlot": false, "to ...
#
# var gd = document.getElementById('a9a1ebd9-a964-4ab1-b5bb-ebb6c0aa5da2');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                            </script>        </div>
# </body>
# </html>
# (0.0, 1.5)

# %% [markdown]
# Interpretasi : <br>
# Berdasarkan permutation feature importance model logistic regression, marital status, education-num, capital-gain, age hours-per-week yang paling mempengaruhi target.

# %%
# visualisasi permutation feature importance untuk XGBoost Model
plt.figure(figsize=(8, 10))
xgb_exp.model_parts().plot()
ax.set_xlim(left=0)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c2a69060-d4d2-46e2-8eb1-2cca452ced6c" class="plotly-graph-div" style="height:383.0px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c2a69060-d4d2-46e2-8eb1-2cca452ced6c")) {                    Plotly.newPlot(                        "c2a69060-d4d2-46e2-8eb1-2cca452ced6c",                        [{"base":0.04271962532896828,"hoverinfo":"text","hoverlabel":{"bgcolor":"rgba(0,0,0,0.8)"},"hovertext":["Model: XGBoost Interpretation loss after\u003cbr\u003evariable: marital-status_encoded is permuted: 0.128\u003cbr\u003eDrop-out loss change: +0.086","Model: XGBoost Interpretation loss after\u003cbr\u003evariable: age is permuted: 0.105\u003cbr\u003eDrop-out loss change: +0.062","Model: XGBoost Interpretation loss after\u003cbr\u003evariable: capital-gain is permuted: 0.102\u003cbr\u003eDrop-out loss change: +0.06","Model: XGBoost Interpretation loss after\u003cbr\u003evariable: education-num is permuted: 0.073\u003cbr\u003eDrop-out loss change: +0.03","Model: XGBoost Interpretation loss after\u003cbr\u003evariable: hours-per-week is permuted: 0.068\u003cbr\u003eDrop-out loss change: +0.026","Model: XGBoost Interpretation loss after\u003cbr\u003evariable: occupation_encoded is permuted: 0.063\u003cbr\u003eDrop-out loss change: +0.02","Model: XGBoost Interpretation loss after\u003cbr\u003evariable: fnlwgt is permuted: 0.06\u003cbr\u003eDrop-out loss change: +0.017","Model: XGBoost Interpretation loss after\u003cbr\u003evariable: capital-loss is permuted: 0.058\u003cbr\u003eDrop-out loss change: +0.015","Model: XGBoost Interpretation loss after\u003cbr\u003evariable: relationship_encoded is permuted: 0.051\u003cbr\u003eDrop-out loss change: +0.008","Model: XGBoost Interpretation loss after\u003cbr\u003evariable: workclass_encoded is permuted: 0.05\u003cbr\u003eDrop-out loss change: +0.007"],"marker":{"color":"#46bac2"},"orientation":"h","showlegend":false,"text":["+0.086","+0.062","+0.06","+0.03","+0.026","+0.02","+0.017","+0.015","+0.008","+0.007"],"textposition":"outside","x":[0.08563775103469934,0.06246656934821014,0.0597774317203881,0.029867321462006588,0.02556872575329723,0.02015452743638281,0.017237696582699615,0.015262612305606028,0.007936046974207911,0.007229443746850861],"y":["marital-status_encoded","age","capital-gain","education-num","hours-per-week","occupation_encoded","fnlwgt","capital-loss","relationship_encoded","workclass_encoded"],"type":"bar","xaxis":"x","yaxis":"y"}],                        {"template":{"data":{"scatter":[{"type":"scatter"}]}},"xaxis":{"anchor":"y","domain":[0.0,1.0],"type":"linear","gridwidth":2,"zeroline":false,"automargin":true,"ticks":"outside","tickcolor":"white","ticklen":3,"fixedrange":true,"range":[0.029873962673763382,0.14120303901887252]},"yaxis":{"anchor":"x","domain":[0.0,1.0],"type":"category","autorange":"reversed","gridwidth":2,"automargin":true,"ticks":"outside","tickcolor":"white","ticklen":10,"fixedrange":true},"annotations":[{"font":{"size":16},"showarrow":false,"text":"XGBoost Interpretation","x":0.5,"xanchor":"center","xref":"paper","y":1.0,"yanchor":"bottom","yref":"paper"},{"font":{"size":16},"showarrow":false,"text":"drop-out loss","x":0.5,"xanchor":"center","xref":"paper","y":0,"yanchor":"top","yref":"paper","yshift":-30}],"shapes":[{"line":{"color":"#371ea3","dash":"dot","width":1.5},"type":"line","x0":0.04271962532896828,"x1":0.04271962532896828,"xref":"x","y0":-1,"y1":10,"yref":"y"}],"title":{"text":"Variable Importance","x":0.15},"font":{"color":"#371ea3"},"margin":{"t":78,"b":71,"r":30},"height":383.0},                        {"displaylogo": false, "staticPlot": false, "toImageButtonOptions": {"height": null, "width": null}, "modeBarButtonsToRemove": ["sendDataToCloud", "lasso2d", "autoScale2d", "select2d ...
#
# var gd = document.getElementById('c2a69060-d4d2-46e2-8eb1-2cca452ced6c');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                            </script>        </div>
# </body>
# </html>
# (0.0, 1.5)

# %% [markdown]
# Interpretasi : <BR>
# Berdasarkan permutation feature importance model xgboost, marital status, age, capital-gain, education-num, hours-per-week yang paling mempengaruhi target (sama seperti model logistic regression hanya saja urutannya berbeda)
